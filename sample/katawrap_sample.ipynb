# %% [markdown]
# # Sample for katawrap with Python

# %%
#ls Test/*.sgf | ./katawrap.py -visits 400 -human_rank rank_1d ../../KataGo/katago analysis -config analysis_example.cfg -model default_model.bin.gz -human-model b18c384nbt-humanv0.bin.gz > results.jsonl

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# Edit the next line if you want to try your own data. See README.md on how to prepare *.josnl.

# %%
input_file = 'results.jsonl'

# %% [markdown]
# Load results of katawrap.

# %%
df = pd.read_json(input_file, lines=True)

# %% [markdown]
# Show some basic fields.

# %%
keys = ['sgfFile', 'turnNumber', 'winrate', 'scoreLead']

df[keys]
# Out:
#                                       sgfFile  turnNumber   winrate  scoreLead
# 0     Test/66927213-308-seahorse1-tmswngr.sgf           0  0.470806  -0.351893
# 1     Test/66927213-308-seahorse1-tmswngr.sgf           1  0.473900  -0.339788
# 2     Test/66927213-308-seahorse1-tmswngr.sgf           2  0.472816  -0.346492
# 3     Test/66927213-308-seahorse1-tmswngr.sgf           3  0.464101  -0.372894
# 4     Test/66927213-308-seahorse1-tmswngr.sgf           4  0.463812  -0.382624
# ...                                       ...         ...       ...        ...
# 1523   Test/66978320-110-seahorse1-Daniul.sgf         106  0.466262  -0.138228
# 1524   Test/66978320-110-seahorse1-Daniul.sgf         107  0.338069  -1.245396
# 1525   Test/66978320-110-seahorse1-Daniul.sgf         108  0.433826  -0.388083
# 1526   Test/66978320-110-seahorse1-Daniul.sgf         109  0.329130  -1.223335
# 1527   Test/66978320-110-seahorse1-Daniul.sgf         110  0.317357  -1.395637
#
# [1528 rows x 4 columns]

# %% [markdown]
# ...and more fields

# %%
keys = [k for k in [
    'sgfFile', 'PB', 'PW', 'RE', 'rules', 'komi',
    'turnNumber', 'currentPlayer',
    'winrate', 'scoreLead', 'unsettledness',
    'nextMove', 'nextMoveColor', 'nextMoveSign',
    'nextMoveRank', 'nextWinrateGain', 'nextScoreGain',
] if k in df.keys()]

df[keys]
# Out:
#                                       sgfFile       PB         PW      RE  \
# 0     Test/66927213-308-seahorse1-tmswngr.sgf  tmswngr  seahorse1  W+13.5
# 1     Test/66927213-308-seahorse1-tmswngr.sgf  tmswngr  seahorse1  W+13.5
# 2     Test/66927213-308-seahorse1-tmswngr.sgf  tmswngr  seahorse1  W+13.5
# 3     Test/66927213-308-seahorse1-tmswngr.sgf  tmswngr  seahorse1  W+13.5
# 4     Test/66927213-308-seahorse1-tmswngr.sgf  tmswngr  seahorse1  W+13.5
# ...                                       ...      ...        ...     ...
# 1523   Test/66978320-110-seahorse1-Daniul.sgf   Daniul  seahorse1     W+T
# 1524   Test/66978320-110-seahorse1-Daniul.sgf   Daniul  seahorse1     W+T
# 1525   Test/66978320-110-seahorse1-Daniul.sgf   Daniul  seahorse1     W+T
# 1526   Test/66978320-110-seahorse1-Daniul.sgf   Daniul  seahorse1     W+T
# 1527   Test/66978320-110-seahorse1-Daniul.sgf   Daniul  seahorse1     W+T
#
#          rules  komi  turnNumber currentPlayer   winrate  scoreLead  \
# 0     japanese   6.5           0             B  0.470806  -0.351893
# 1     japanese   6.5           1             W  0.473900  -0.339788
# 2     japanese   6.5           2             B  0.472816  -0.346492
# 3     japanese   6.5           3             W  0.464101  -0.372894
# 4     japanese   6.5           4             B  0.463812  -0.382624
# ...        ...   ...         ...           ...       ...        ...
# 1523  japanese   6.5         106             B  0.466262  -0.138228
# 1524  japanese   6.5         107             W  0.338069  -1.245396
# 1525  japanese   6.5         108             B  0.433826  -0.388083
# 1526  japanese   6.5         109             W  0.329130  -1.223335
# 1527  japanese   6.5         110             B  0.317357  -1.395637
#
#       unsettledness nextMove nextMoveColor  nextMoveSign  nextMoveRank  \
# 0          0.000000      Q16             B           1.0           0.0
# 1          0.226234       Q4             W          -1.0           1.0
# 2          0.490440      D17             B           1.0           8.0
# 3          0.708912       D4             W          -1.0           0.0
# 4          0.902884       R6             B           1.0           7.0
# ...             ...      ...           ...           ...           ...
# 1523      20.097106      M12             B           1.0           4.0
# 1524      18.408512      N14             W          -1.0          12.0
# 1525      18.862107      G12             B           1.0          19.0
# 1526      15.590415      G11             W          -1.0           0.0
# 1527      16.016470      NaN           NaN           NaN           NaN
#
#       nextWinrateGain  nextScoreGain
# 0            0.003094       0.012104
# 1            0.001084       0.006703
# 2           -0.008715      -0.026403
# 3            0.000289       0.009730
# 4           -0.004243      -0.039611
# ...               ...            ...
# 1523        -0.128194      -1.107168
# 1524        -0.095757      -0.857313
# 1525        -0.104695      -0.835253
# 1526         0.011773       0.172302
# 1527              NaN            NaN
#
# [1528 rows x 17 columns]

# %% [markdown]
# List all field names.

# %%
df.keys()
# Out:
# Index(['humanPolicy', 'id', 'isDuringSearch', 'moveInfos', 'ownership',
#        'policy', 'rootInfo', 'turnNumber', 'includeUnsettledness', 'sgfFile',
#        'visits', 'last', 'moves', 'boardXSize', 'boardYSize', 'initialPlayer',
#        'komi', 'rules', 'maxVisits', 'analyzeLastTurn', 'analyzeTurns',
#        'includeOwnership', 'includePolicy', 'overrideSettings', 'sgfProp',
#        'sgf', 'FF', 'CA', 'GM', 'DT', 'PC', 'GN', 'PB', 'PW', 'BR', 'WR', 'TM',
#        'OT', 'RE', 'SZ', 'KM', 'RU', 'currentPlayer', 'humanScoreMean',
#        'humanScoreStdev', 'humanStScoreError', 'humanStWrError',
#        'humanWinrate', 'rawLead', 'rawNoResultProb', 'rawScoreSelfplay',
#        'rawScoreSelfplayStdev', 'rawStScoreError', 'rawStWrError',
#        'rawVarTimeLeft', 'rawWinrate', 'scoreLead', 'scoreSelfplay',
#        'scoreStdev', 'symHash', 'thisHash', 'utility', 'weight', 'winrate',
#        'nextMove', 'nextMoveColor', 'nextMoveSign', 'nextMoveRank', 'query',
#        'board', 'blackUnsettledness', 'whiteUnsettledness',
#        'territoryUnsettledness', 'unsettledness', 'nextRootInfo',
#        'nextWinrateGain', 'nextScoreGain', 'initialStones', 'AB', 'C'],
#       dtype='object')

# %% [markdown]
# Find the worst blunders, up to 5 in each game

# %%
keys = [
    'sgfFile', 'PB', 'PW', 'turnNumber','nextMove','nextMoveColor',
    'scoreLead', 'nextScoreGain', 'nextWinrateGain',"moveInfos"]
blunders=df[keys]
blunders=blunders.query('nextWinrateGain < -0.1')
blunders=blunders.query('nextScoreGain < -3.0 ')
blunders=blunders.sort_values(["sgfFile","nextScoreGain"])
blunders=blunders.groupby(["sgfFile"]).head(5).reset_index(drop=True)

blunders
# Out:
#                                               sgfFile              PB  \
# 0             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 1             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 2             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 3             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 4             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 5   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 6   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 7   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 8   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 9   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 10         Test/66942690-048-olimar-seahorse1 (1).sgf       seahorse1
# 11             Test/66942690-048-olimar-seahorse1.sgf       seahorse1
# 12             Test/66945951-163-seahorse1-8899go.sgf          8899go
# 13     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 14     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 15     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 16     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 17     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 18         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 19         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 20         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 21         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 22         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 23      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 24      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 25      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 26      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 27      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 28             Test/66978320-110-seahorse1-Daniul.sgf          Daniul
# 29             Test/66978320-110-seahorse1-Daniul.sgf          Daniul
# 30             Test/66978320-110-seahorse1-Daniul.sgf          Daniul
#
#                PW  turnNumber nextMove nextMoveColor  scoreLead  \
# 0       seahorse1         138       G7             B  27.516262
# 1       seahorse1         139       K6             W -15.013045
# 2       seahorse1         135      J13             W  -6.922759
# 3       seahorse1         146      K14             B  23.625760
# 4       seahorse1         124      F11             B  18.127799
# 5   Бобер Кармаль         195       Q4             B  19.132317
# 6   Бобер Кармаль         194       N3             W -61.350132
# 7   Бобер Кармаль         191       O1             B  17.909887
# 8   Бобер Кармаль         190       O2             W -60.588984
# 9   Бобер Кармаль         189       P1             B  16.578829
# 10         olimar          44      H17             B   3.994479
# 11         olimar          44      H17             B   3.994067
# 12      seahorse1          10      D16             B  -1.524199
# 13      seahorse1          54       E4             B   8.839648
# 14      seahorse1         149       K3             W  10.322015
# 15      seahorse1         148       J3             B  17.518127
# 16      seahorse1          89      H14             W   3.072938
# 17      seahorse1          57       H7             W  -3.630349
# 18     2147483647          83       M6             W  -1.501844
# 19     2147483647          81       N1             W  -7.020880
# 20     2147483647          48       K4             B   3.863017
# 21     2147483647          76      O14             B  -0.993708
# 22     2147483647          47      R12             W   0.781918
# 23      Teo010403          90       G4             B  -8.637526
# 24      Teo010403          68       J4             B   3.220577
# 25      Teo010403          85      K10             W -13.217172
# 26      Teo010403          64       L3             B  13.791888
# 27      Teo010403          47       N7             W   0.656918
# 28      seahorse1          74      D10             B  -3.696460
# 29      seahorse1          97      Q11             W  -7.031628
# 30      seahorse1          99      Q10             W  -3.694238
#
#     nextScoreGain  nextWinrateGain  \
# 0      -42.529307        -0.962518
# 1      -36.999995        -0.940331
# 2      -34.390495        -0.920593
# 3      -33.927016        -0.960343
# 4      -18.194511        -0.403338
# 5      -81.709959        -0.987775
# 6      -80.482450        -0.983267
# 7      -80.056691        -0.985779
# 8      -78.498871        -0.991297
# 9      -77.167813        -0.991183
# 10     -26.389404        -0.815937
# 11     -26.552297        -0.814151
# 12      -5.626344        -0.281828
# 13     -12.088138        -0.656786
# 14     -10.656188        -0.199938
# 15      -7.196112        -0.250286
# 16      -7.136318        -0.230931
# 17      -4.841140        -0.317400
# 18     -17.861589        -0.684703
# 19      -5.242223        -0.254792
# 20      -3.377975        -0.291706
# 21      -3.243126        -0.263399
# 22      -3.081099        -0.256099
# 23     -34.345118        -0.136033
# 24     -14.784285        -0.651811
# 25     -12.280939        -0.248507
# 26     -10.078707        -0.184104
# 27      -5.682388        -0.332394
# 28      -4.910938        -0.116120
# 29      -3.466855        -0.112499
# 30      -3.367793        -0.283709
#
#                                             moveInfos
# 0   [{'edgeVisits': 309, 'edgeWeight': 475.565541,...
# 1   [{'edgeVisits': 398, 'edgeWeight': 1003.73243,...
# 2   [{'edgeVisits': 464, 'edgeWeight': 765.767922,...
# 3   [{'edgeVisits': 196, 'edgeWeight': 243.151576,...
# 4   [{'edgeVisits': 282, 'edgeWeight': 179.125507,...
# 5   [{'edgeVisits': 107, 'edgeWeight': 593.071221,...
# 6   [{'edgeVisits': 372, 'edgeWeight': 2453.07113,...
# 7   [{'edgeVisits': 151, 'edgeWeight': 862.851768,...
# 8   [{'edgeVisits': 479, 'edgeWeight': 2715.11153,...
# 9   [{'edgeVisits': 117, 'edgeWeight': 669.964829,...
# 10  [{'edgeVisits': 510, 'edgeWeight': 685.622919,...
# 11  [{'edgeVisits': 472, 'edgeWeight': 625.017193,...
# 12  [{'edgeVisits': 499, 'edgeWeight': 1061.31167,...
# 13  [{'edgeVisits': 411, 'edgeWeight': 657.258888,...
# 14  [{'edgeVisits': 490, 'edgeWeight': 262.255792,...
# 15  [{'edgeVisits': 208, 'edgeWeight': 566.189373,...
# 16  [{'edgeVisits': 301, 'edgeWeight': 277.288667,...
# 17  [{'edgeVisits': 346, 'edgeWeight': 331.266502,...
# 18  [{'edgeVisits': 298, 'edgeWeight': 353.663764,...
# 19  [{'edgeVisits': 317, 'edgeWeight': 725.778533,...
# 20  [{'edgeVisits': 328, 'edgeWeight': 516.728275,...
# 21  [{'edgeVisits': 196, 'edgeWeight': 247.78448, ...
# 22  [{'edgeVisits': 516, 'edgeWeight': 760.918851,...
# 23  [{'edgeVisits': 481, 'edgeWeight': 391.270414,...
# 24  [{'edgeVisits': 219, 'edgeWeight': 189.455867,...
# 25  [{'edgeVisits': 536, 'edgeWeight': 319.727287,...
# 26  [{'edgeVisits': 226, 'edgeWeight': 321.795783,...
# 27  [{'edgeVisits': 422, 'edgeWeight': 534.997976,...
# 28  [{'edgeVisits': 337, 'edgeWeight': 518.863283,...
# 29  [{'edgeVisits': 481, 'edgeWeight': 1014.27799,...
# 30  [{'edgeVisits': 509, 'edgeWeight': 684.551838,...

# %%
df_exploded=blunders.explode('moveInfos')
df_expanded = pd.concat([
    df_exploded.drop('moveInfos', axis=1),
    df_exploded['moveInfos'].apply(pd.Series)
], axis=1)

# Reset the index if needed
df_expanded = df_expanded.reset_index(drop=True)

df_expanded=df_expanded.sort_values(["sgfFile","turnNumber","order"])

df_expanded=df_expanded.groupby(["sgfFile","turnNumber"]).head(1).reset_index(drop=True)

keys=keys = [
    'sgfFile', 'PB', 'PW', 'turnNumber','nextMove','nextMoveColor',
    'scoreLead', 'nextScoreGain', 'nextWinrateGain',"move","pv","prior","humanPrior"]
df_expanded=df_expanded[keys]
#df_expanded=df_expanded.query('humanPrior>0.1').reset_index(drop=True)
df_expanded
# Out:
#                                               sgfFile              PB  \
# 0             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 1             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 2             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 3             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 4             Test/66927213-308-seahorse1-tmswngr.sgf         tmswngr
# 5   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 6   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 7   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 8   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 9   Test/66940466-208-Бобер Кармаль-seahorse1 (7).sgf       seahorse1
# 10         Test/66942690-048-olimar-seahorse1 (1).sgf       seahorse1
# 11             Test/66942690-048-olimar-seahorse1.sgf       seahorse1
# 12             Test/66945951-163-seahorse1-8899go.sgf          8899go
# 13     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 14     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 15     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 16     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 17     Test/66947329-173-seahorse1-laowantong9999.sgf  laowantong9999
# 18         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 19         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 20         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 21         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 22         Test/66948891-098-2147483647-seahorse1.sgf       seahorse1
# 23      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 24      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 25      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 26      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 27      Test/66977375-094-Teo010403-seahorse1 (1).sgf       seahorse1
# 28             Test/66978320-110-seahorse1-Daniul.sgf          Daniul
# 29             Test/66978320-110-seahorse1-Daniul.sgf          Daniul
# 30             Test/66978320-110-seahorse1-Daniul.sgf          Daniul
#
#                PW  turnNumber nextMove nextMoveColor  scoreLead  scoreLead  \
# 0       seahorse1         124      F11             B  18.127799  18.744184
# 1       seahorse1         135      J13             W  -6.922759  -7.098196
# 2       seahorse1         138       G7             B  27.516262  28.116000
# 3       seahorse1         139       K6             W -15.013045 -15.094688
# 4       seahorse1         146      K14             B  23.625760  23.788438
# 5   Бобер Кармаль         189       P1             B  16.578829  16.720507
# 6   Бобер Кармаль         190       O2             W -60.588984 -60.591265
# 7   Бобер Кармаль         191       O1             B  17.909887  17.998588
# 8   Бобер Кармаль         194       N3             W -61.350132 -63.081003
# 9   Бобер Кармаль         195       Q4             B  19.132317  18.734725
# 10         olimar          44      H17             B   3.994479   3.999658
# 11         olimar          44      H17             B   3.994067   3.999747
# 12      seahorse1          10      D16             B  -1.524199  -1.523142
# 13      seahorse1          54       E4             B   8.839648   8.986861
# 14      seahorse1          57       H7             W  -3.630349  -3.803309
# 15      seahorse1          89      H14             W   3.072938   2.736241
# 16      seahorse1         148       J3             B  17.518127  17.311123
# 17      seahorse1         149       K3             W  10.322015   9.982617
# 18     2147483647          47      R12             W   0.781918   0.782723
# 19     2147483647          48       K4             B   3.863017   3.920206
# 20     2147483647          76      O14             B  -0.993708  -0.915114
# 21     2147483647          81       N1             W  -7.020880  -7.114025
# 22     2147483647          83       M6             W  -1.501844  -1.567012
# 23      Teo010403          47       N7             W   0.656918   0.624413
# 24      Teo010403          64       L3             B  13.791888  14.521568
# 25      Teo010403          68       J4             B   3.220577   3.443805
# 26      Teo010403          85      K10             W -13.217172 -13.343704
# 27      Teo010403          90       G4             B  -8.637526  -7.580701
# 28      seahorse1          74      D10             B  -3.696460  -3.684258
# 29      seahorse1          97      Q11             W  -7.031628  -7.043673
# 30      seahorse1          99      Q10             W  -3.694238  -3.693872
#
#     nextScoreGain  nextWinrateGain move  \
# 0      -18.194511        -0.403338   L9
# 1      -34.390495        -0.920593  J12
# 2      -42.529307        -0.962518   F7
# 3      -36.999995        -0.940331  F12
# 4      -33.927016        -0.960343  F12
# 5      -77.167813        -0.991183   M8
# 6      -78.498871        -0.991297   M7
# 7      -80.056691        -0.985779   M8
# 8      -80.482450        -0.983267   M7
# 9      -81.709959        -0.987775   N8
# 10     -26.389404        -0.815937  J15
# 11     -26.552297        -0.814151  J15
# 12      -5.626344        -0.281828  D15
# 13     -12.088138        -0.656786   E5
# 14      -4.841140        -0.317400   H3
# 15      -7.136318        -0.230931  H17
# 16      -7.196112        -0.250286   P4
# 17     -10.656188        -0.199938   Q5
# 18      -3.081099        -0.256099  S14
# 19      -3.377975        -0.291706  S14
# 20      -3.243126        -0.263399   C4
# 21      -5.242223        -0.254792  R18
# 22     -17.861589        -0.684703   K6
# 23      -5.682388        -0.332394   J3
# 24     -10.078707        -0.184104   H5
# 25     -14.784285        -0.651811  M10
# 26     -12.280939        -0.248507   J9
# 27     -34.345118        -0.136033   J9
# 28      -4.910938        -0.116120  F10
# 29      -3.466855        -0.112499  S13
# 30      -3.367793        -0.283709  S13
#
#                                                    pv     prior  humanPrior
# 0         [L9, K11, K8, C10, H12, F11, H13, E13, D13]  0.410443    0.074474
# 1   [J12, D18, O17, K13, M10, M12, L13, K14, M13, ...  0.300470    0.216488
# 2      [F7, F10, E6, E4, G10, F6, H11, J12, M10, G11]  0.286601    0.231552
# 3   [F12, K12, K13, L11, M11, M12, L13, M10, N11, ...  0.897408    0.304867
# 4                 [F12, M12, N10, M7, K7, M8, O7, M6]  0.256291    0.025560
# 5                            [M8, E15, E16, C17, C16]  0.357136    0.144859
# 6                               [M7, D5, E4, B9, B10]  0.970102    0.014131
# 7                          [M8, O1, B9, E5, E15, N17]  0.445729    0.025450
# 8                    [M7, L7, J7, D5, E4, N2, N3, M1]  0.154020    0.043494
# 9                       [N8, E15, E16, C17, C16, B17]  0.215940    0.015485
# 10  [J15, G16, J16, F17, D14, H17, D11, H12, H18, ...  0.998175    0.955092
# 11  [J15, G16, J16, F17, D14, H17, D11, H12, H18, ...  0.998175    0.954447
# 12  [D15, G16, F14, G15, R6, O4, N4, O5, Q3, R3, P...  0.959607    0.160535
# 13  [E5, E9, D11, E10, C12, G5, G6, J5, B1, A2, J6...  0.663216    0.422218
# 14      [H3, B1, A2, E9, F9, G7, F8, H8, F10, B4, A4]  0.230014    0.072468
# 15  [H17, J16, G17, M15, L14, L15, M14, B1, A2, G3...  0.040082    0.024877
# 16               [P4, L6, M7, K3, K2, J2, O4, K8, M9]  0.136189    0.004855
# 17               [Q5, S4, L6, M7, Q7, J6, K6, N8, L8]  0.670702    0.089650
# 18  [S14, R16, M16, Q7, R8, Q8, C10, M17, L16, N16...  0.965803    0.761674
# 19  [S14, C10, S12, L15, F14, D12, C11, D11, B10, ...  0.563338    0.050709
# 20  [C4, R18, S18, M1, M2, O18, S16, L2, S7, S8, M...  0.096759    0.010971
# 21  [R18, S18, O18, S16, L17, F14, L18, K12, L12, ...  0.628080    0.049976
# 22  [K6, M5, M6, N5, R18, S18, N6, O5, O18, S16, L...  0.100334    0.438428
# 23  [J3, H4, J4, R9, P8, N9, O10, M6, J5, O9, P9, ...  0.434029    0.007243
# 24  [H5, J6, J5, K5, K6, G2, H2, J7, L8, G4, G3, H...  0.358806    0.077646
# 25  [M10, L9, F4, G2, G3, H2, J3, J4, F5, K5, K6, ...  0.451080    0.071787
# 26  [J9, S7, R7, H7, G6, K10, M10, L11, M11, H8, G...  0.658834    0.211587
# 27          [J9, G4, R10, S9, B2, M11, N11, N12, O11]  0.643532    0.693500
# 28  [F10, E11, F11, E12, Q7, L5, F12, E13, L6, K6,...  0.824209    0.664151
# 29  [S13, T11, Q11, R10, Q9, Q10, P9, R8, P10, P11...  0.566481    0.056082
# 30  [S13, Q10, N16, N15, O14, O15, P11, O12, P10, ...  0.900306    0.749123
